# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# der er V(g)= 3 + 1 = 4 unikke lineær basic paths
#
# 1-2-6
#
# 1-2-3-6
#
# 1-2-3-4-6
#
# 1-2-3-4-5-6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# der er V(g) = 1+1 = 2 unikke lineær basic paths
#
# 1-2-3-5
#
# 1-2-4-5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# der er V(g)= 1+1 = 2 unikke lineær basic paths
#
# 1-2-3
#
# 1-2-4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# der er V(g) = 4 + 1 = 5 unikke lineær basic paths
#
# 1-2-4
#
# 1-2-3-4
#
# 1-2-3-4-5-6
#
# 1-2-3-4-5-7-8
#
# 1-2-3-4-5-7-9

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <!-- V(g)= 6 + 1 = 7 unikke lineær basic paths
#
# 1-2-4-12
#
# 1-2-3-4-12
#
# 1-2-3-5-7-12
#
# 1-2-3-5-6-7-12
#
# 1-2-3-5-6-8-9-12
#
# 1-2-3-5-6-8-9-10-12
#
# 1-2-3-5-6-8-9-11-12 -->

# %% [markdown]
# 1-2-3-4-12
#
# 1-2-3-5-6-7-12
#
# 1-2-5-6-7-12
#
# 1-2-5-6-8-9-10-12
#
# 1-2-3-5-8-11-12
#
# 1-2-5-8-9-11-12
#
# 1-2-5-8-11-12
